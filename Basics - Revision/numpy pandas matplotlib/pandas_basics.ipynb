# %%
import pandas as pd

listy = [1, 2, 3, 4]
seriesy = pd.Series(listy)
seriesy
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
seriesy[3]
# Out:
# np.int64(4)

# %%
my_index = ["A", "B", "C", "L"]
seriesy_2 = pd.Series(listy, my_index)
seriesy_2
# Out:
# A    1
# B    2
# C    3
# L    4
# dtype: int64

# %%
print(seriesy_2["L"])
# Out:
# 4

# %%
cars = {"tesla": 12, "BMW": 10, "Nissan": 20}
series_3 = pd.Series(cars)
series_3
# Out:
# tesla     12
# BMW       10
# Nissan    20
# dtype: int64

# %%
from numpy.random import randn

data = randn(4, 3)  # 4 rows and 3 columns
data
# Out:
# array([[ 0.48883635,  0.01547205, -1.15113188],
#        [-1.02591682,  0.46099422, -0.20160391],
#        [ 1.34667606, -2.68010311,  1.31473007],
#        [-1.13917192, -1.41944757, -0.18207957]])

# %%
rows = ["A", "B", "C", "D"]
cols = ["mon", "tues", "wed"]
df = pd.DataFrame(data, rows, cols)
df
# Out:
#         mon      tues       wed
# A  0.488836  0.015472 -1.151132
# B -1.025917  0.460994 -0.201604
# C  1.346676 -2.680103  1.314730
# D -1.139172 -1.419448 -0.182080

# %%
gas = pd.read_csv("gas_prices.csv")
gas.head(5)
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
gas.loc[0]
# Out:
# Year           1990.00
# Australia          NaN
# Canada            1.87
# France            3.63
# Germany           2.65
# Italy             4.59
# Japan             3.16
# Mexico            1.00
# South Korea       2.05
# UK                2.82
# USA               1.16
# Name: 0, dtype: float64

# %%
gas.loc[[0, 3, 2, 1]]
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 3         2.88  2.84  1.11
# 2         2.65  3.06  1.13
# 1         2.49  3.01  1.14

# %%
gas.loc[0:2]
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16     1.0
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46     1.3
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58     1.5
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13

# %%
gas.loc[0:]
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
gas.loc[0:10:2]
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
#
#     South Korea    UK   USA
# 0          2.05  2.82  1.16
# 2          2.65  3.06  1.13
# 4          2.87  2.99  1.11
# 6          3.18  3.34  1.23
# 8          3.04  4.06  1.06
# 10         4.18  4.58  1.51

# %%
gas.loc[:4]
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
gas.head(5)
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
gas.loc[[3]]
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
#
#    South Korea    UK   USA
# 3         2.88  2.84  1.11

# %%
df
# Out:
#         mon      tues       wed
# A  0.488836  0.015472 -1.151132
# B -1.025917  0.460994 -0.201604
# C  1.346676 -2.680103  1.314730
# D -1.139172 -1.419448 -0.182080

# %%
df.loc["A":"C"]
# Out:
#         mon      tues       wed
# A  0.488836  0.015472 -1.151132
# B -1.025917  0.460994 -0.201604
# C  1.346676 -2.680103  1.314730

# %%
gas.tail(5)
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 14  2004       2.72    2.37    4.99     5.24   5.29   3.93    2.03
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA
# 14         4.51  5.56  1.88
# 15         5.28  5.97  2.30
# 16         5.92  6.36  2.59
# 17         6.21  7.13  2.80
# 18         5.83  7.42  3.27

# %%
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         19 non-null     int64
#  1   Australia    18 non-null     float64
#  2   Canada       19 non-null     float64
#  3   France       19 non-null     float64
#  4   Germany      19 non-null     float64
#  5   Italy        19 non-null     float64
#  6   Japan        19 non-null     float64
#  7   Mexico       19 non-null     float64
#  8   South Korea  19 non-null     float64
#  9   UK           19 non-null     float64
#  10  USA          19 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 1.8 KB

# %%
gas.shape
# Out:
# (19, 11)

# %%
gas.ndim
# Out:
# 2

# %%
gas.dtypes
# Out:
# Year             int64
# Australia      float64
# Canada         float64
# France         float64
# Germany        float64
# Italy          float64
# Japan          float64
# Mexico         float64
# South Korea    float64
# UK             float64
# USA            float64
# dtype: object

# %%
gas.describe()
# Out:
#               Year  Australia     Canada     France    Germany      Italy  \
# count    19.000000  18.000000  19.000000  19.000000  19.000000  19.000000
# mean   1999.000000   2.348889   2.086842   4.407895   4.224737   4.645789
# std       5.627314   0.845931   0.786618   1.167531   1.425749   1.146610
# min    1990.000000   1.630000   1.380000   3.410000   2.650000   3.570000
# 25%    1994.500000   1.780000   1.590000   3.605000   3.370000   3.805000
# 50%    1999.000000   1.955000   1.730000   3.870000   3.530000   4.390000
# 75%    2003.500000   2.587500   2.180000   4.700000   4.915000   4.940000
# max    2008.000000   4.450000   4.080000   7.510000   7.750000   7.630000
#
#            Japan     Mexico  South Korea         UK        USA
# count  19.000000  19.000000    19.000000  19.000000  19.000000
# mean    3.820526   1.781579     3.835789   4.392632   1.592105
# std     0.696615   0.462148     1.226170   1.455170   0.663355
# ...

# %%
gas["USA"].describe()
# Out:
# count    19.000000
# mean      1.592105
# std       0.663355
# min       1.060000
# 25%       1.145000
# 50%       1.230000
# 75%       1.735000
# max       3.270000
# Name: USA, dtype: float64

# %%
gas["Australia"]
# Out:
# 0      NaN
# 1     1.96
# 2     1.89
# 3     1.73
# 4     1.84
# 5     1.95
# 6     2.12
# 7     2.05
# 8     1.63
# 9     1.72
# 10    1.94
# 11    1.71
# 12    1.76
# 13    2.19
# 14    2.72
# 15    3.23
# 16    3.54
# 17    3.85
# 18    4.45
# Name: Australia, dtype: float64

# %%
gas.USA
# Out:
# 0     1.16
# 1     1.14
# 2     1.13
# 3     1.11
# 4     1.11
# 5     1.15
# 6     1.23
# 7     1.23
# 8     1.06
# 9     1.17
# 10    1.51
# 11    1.46
# 12    1.36
# 13    1.59
# 14    1.88
# 15    2.30
# 16    2.59
# 17    2.80
# 18    3.27
# Name: USA, dtype: float64

# %%
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
gas.iloc[0:5, 0]
# Out:
# 0    1990
# 1    1991
# 2    1992
# 3    1993
# 4    1994
# Name: Year, dtype: int64

# %%
gas["USA"].value_counts()
# Out:
# USA
# 1.11    2
# 1.23    2
# 1.16    1
# 1.13    1
# 1.14    1
# 1.15    1
# 1.06    1
# 1.17    1
# 1.51    1
# 1.46    1
# 1.36    1
# 1.59    1
# 1.88    1
# 2.30    1
# 2.59    1
# 2.80    1
# 3.27    1
# Name: count, dtype: int64

# %%
gas["USA"].value_counts(ascending=True)
# Out:
# USA
# 1.16    1
# 1.14    1
# 1.13    1
# 1.15    1
# 1.17    1
# 1.06    1
# 1.46    1
# 1.51    1
# 1.88    1
# 2.30    1
# 1.36    1
# 1.59    1
# 2.59    1
# 2.80    1
# 3.27    1
# 1.23    2
# 1.11    2
# Name: count, dtype: int64

# %%
gas["Australia"].value_counts(dropna=False)
# Out:
# Australia
# NaN     1
# 1.96    1
# 1.89    1
# 1.73    1
# 1.84    1
# 1.95    1
# 2.12    1
# 2.05    1
# 1.63    1
# 1.72    1
# 1.94    1
# 1.71    1
# 1.76    1
# 2.19    1
# 2.72    1
# 3.23    1
# 3.54    1
# 3.85    1
# 4.45    1
# Name: count, dtype: int64

# %%
gas["Australia"].value_counts(normalize=True)
# Out:
# Australia
# 1.96    0.055556
# 1.89    0.055556
# 1.73    0.055556
# 1.84    0.055556
# 1.95    0.055556
# 2.12    0.055556
# 2.05    0.055556
# 1.63    0.055556
# 1.72    0.055556
# 1.94    0.055556
# 1.71    0.055556
# 1.76    0.055556
# 2.19    0.055556
# 2.72    0.055556
# 3.23    0.055556
# 3.54    0.055556
# 3.85    0.055556
# 4.45    0.055556
# Name: proportion, dtype: float64

# %%
gas_small = gas.head(5).copy()

gas_small
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
Pakistan = [0.9, 1.1, 1.2, 0.92, 0.87]
gas_small["Pakistan"] = Pakistan
gas_small
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan
# 0         2.05  2.82  1.16      0.90
# 1         2.49  3.01  1.14      1.10
# 2         2.65  3.06  1.13      1.20
# 3         2.88  2.84  1.11      0.92
# 4         2.87  2.99  1.11      0.87

# %%
Saudi_Arabia = ["1.12"] * len(gas_small)
gas_small["Saudi Arabia"] = Saudi_Arabia
gas_small
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia
# 0         2.05  2.82  1.16      0.90         1.12
# 1         2.49  3.01  1.14      1.10         1.12
# 2         2.65  3.06  1.13      1.20         1.12
# 3         2.88  2.84  1.11      0.92         1.12
# 4         2.87  2.99  1.11      0.87         1.12

# %%
import numpy as np

gas_small["Sweden"] = [np.nan] * len(gas_small)
gas_small
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small.insert(
    1, "Kuwait", [1.67] * len(gas_small), True
)  # True means allow duplicates
gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small2 = gas_small.assign(Dubai=[2.72] * len(gas_small))
gas_small2
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden  Dubai
# 0         2.05  2.82  1.16      0.90         1.12     NaN   2.72
# 1         2.49  3.01  1.14      1.10         1.12     NaN   2.72
# 2         2.65  3.06  1.13      1.20         1.12     NaN   2.72
# 3         2.88  2.84  1.11      0.92         1.12     NaN   2.72
# 4         2.87  2.99  1.11      0.87         1.12     NaN   2.72

# %%
gas_small2.drop("Dubai", axis=1, inplace=True)
gas_small2
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small2.drop(4, axis=0, inplace=True)
gas_small2
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN

# %%
gas_small.loc[1]
# Out:
# Year            1991
# Kuwait          1.67
# Australia       1.96
# Canada          1.92
# France          3.45
# Germany          2.9
# Italy            4.5
# Japan           3.46
# Mexico           1.3
# South Korea     2.49
# UK              3.01
# USA             1.14
# Pakistan         1.1
# Saudi Arabia    1.12
# Sweden           NaN
# Name: 1, dtype: object

# %%
df
# Out:
#         mon      tues       wed
# A  0.488836  0.015472 -1.151132
# B -1.025917  0.460994 -0.201604
# C  1.346676 -2.680103  1.314730
# D -1.139172 -1.419448 -0.182080

# %%
df.loc["A"]
# Out:
# mon     0.488836
# tues    0.015472
# wed    -1.151132
# Name: A, dtype: float64

# %%
df.iloc[0]
# Out:
# mon     0.488836
# tues    0.015472
# wed    -1.151132
# Name: A, dtype: float64

# %%
df
# Out:
#         mon      tues       wed
# A  0.488836  0.015472 -1.151132
# B -1.025917  0.460994 -0.201604
# C  1.346676 -2.680103  1.314730
# D -1.139172 -1.419448 -0.182080

# %%
df.loc["C", "wed"]
# Out:
# np.float64(1.3147300704376457)

# %%
df.loc["A":"C", "tues"]
# Out:
# A    0.015472
# B    0.460994
# C   -2.680103
# Name: tues, dtype: float64

# %%
df.iloc[[0, 3], [0, 2]]
# Out:
#         mon       wed
# A  0.488836 -1.151132
# D -1.139172 -0.182080

# %%
gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small == 1990
# Out:
#     Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   True   False      False   False   False    False  False  False   False
# 1  False   False      False   False   False    False  False  False   False
# 2  False   False      False   False   False    False  False  False   False
# 3  False   False      False   False   False    False  False  False   False
# 4  False   False      False   False   False    False  False  False   False
#
#    South Korea     UK    USA  Pakistan  Saudi Arabia  Sweden
# 0        False  False  False     False         False   False
# 1        False  False  False     False         False   False
# 2        False  False  False     False         False   False
# 3        False  False  False     False         False   False
# 4        False  False  False     False         False   False

# %%
gas_small[gas_small == 1990]
# Out:
#      Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990.0     NaN        NaN     NaN     NaN      NaN    NaN    NaN     NaN
# 1     NaN     NaN        NaN     NaN     NaN      NaN    NaN    NaN     NaN
# 2     NaN     NaN        NaN     NaN     NaN      NaN    NaN    NaN     NaN
# 3     NaN     NaN        NaN     NaN     NaN      NaN    NaN    NaN     NaN
# 4     NaN     NaN        NaN     NaN     NaN      NaN    NaN    NaN     NaN
#
#    South Korea  UK  USA  Pakistan Saudi Arabia  Sweden
# 0          NaN NaN  NaN       NaN          NaN     NaN
# 1          NaN NaN  NaN       NaN          NaN     NaN
# 2          NaN NaN  NaN       NaN          NaN     NaN
# 3          NaN NaN  NaN       NaN          NaN     NaN
# 4          NaN NaN  NaN       NaN          NaN     NaN

# %%
gas_small[gas_small == 1990]["Year"]
# Out:
# 0    1990.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# Name: Year, dtype: float64

# %%
gas_small[gas_small == 1990][["Year", "USA", "Australia"]]
# Out:
#      Year  USA  Australia
# 0  1990.0  NaN        NaN
# 1     NaN  NaN        NaN
# 2     NaN  NaN        NaN
# 3     NaN  NaN        NaN
# 4     NaN  NaN        NaN

# %%
gas_small[gas_small["Year"] >= 1990][["Year", "USA", "Australia"]]
# Out:
#    Year   USA  Australia
# 0  1990  1.16        NaN
# 1  1991  1.14       1.96
# 2  1992  1.13       1.89
# 3  1993  1.11       1.73
# 4  1994  1.11       1.84

# %%
gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small[(gas_small["Year"] == 1993) & (gas_small["USA"] > 1)]
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 3         2.88  2.84  1.11      0.92         1.12     NaN

# %%
len(gas_small[(gas_small["Year"] == 1993) & (gas_small["USA"] > 1)])
# Out:
# 1

# %%
gas_small[(gas_small["Year"] == 1993) | (gas_small["USA"] > 1)]
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small[(gas_small["Year"] == 1993) | (gas_small["USA"] > 1)][["Kuwait", "Australia"]]
# Out:
#    Kuwait  Australia
# 0    1.67        NaN
# 1    1.67       1.96
# 2    1.67       1.89
# 3    1.67       1.73
# 4    1.67       1.84

# %%
gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small.set_index("Year", inplace=True)
gas_small
# Out:
#       Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# Year
# 1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#       South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# Year
# 1990         2.05  2.82  1.16      0.90         1.12     NaN
# 1991         2.49  3.01  1.14      1.10         1.12     NaN
# 1992         2.65  3.06  1.13      1.20         1.12     NaN
# 1993         2.88  2.84  1.11      0.92         1.12     NaN
# 1994         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small.reset_index(inplace=True)
gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
stuff = {"A": [1, 2, 3], "B": [4, np.nan, 6], "C": [7, 8, 9], "D": [10, 11, 12]}
my_df = pd.DataFrame(stuff)
my_df
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 1  2  NaN  8  11
# 2  3  6.0  9  12

# %%
my_df.dropna()
# Out:
#    A    B  C   D
# 0  1  4.0  7  10
# 2  3  6.0  9  12

# %%
my_df.dropna(axis=1)
# Out:
#    A  C   D
# 0  1  7  10
# 1  2  8  11
# 2  3  9  12

# %%
stuff = {
    "A": [1, 2, 3],
    "B": [4, np.nan, np.nan],
    "C": [np.nan, 8, 9],
    "D": [10, 11, 12],
}
my_df = pd.DataFrame(stuff)
my_df
# Out:
#    A    B    C   D
# 0  1  4.0  NaN  10
# 1  2  NaN  8.0  11
# 2  3  NaN  9.0  12

# %%
my_df.dropna(thresh=2, axis=1, inplace=True)
my_df
# Out:
#    A    C   D
# 0  1  NaN  10
# 1  2  8.0  11
# 2  3  9.0  12

# %%
stuff = {
    "A": [1, 2, 3],
    "B": [4, np.nan, np.nan],
    "C": [np.nan, 8, 9],
    "D": [10, 11, 12],
}
my_df = pd.DataFrame(stuff)
my_df
# Out:
#    A    B    C   D
# 0  1  4.0  NaN  10
# 1  2  NaN  8.0  11
# 2  3  NaN  9.0  12

# %%
my_df.fillna(value=42)
# Out:
#    A     B     C   D
# 0  1   4.0  42.0  10
# 1  2  42.0   8.0  11
# 2  3  42.0   9.0  12

# %%
my_df.fillna(value=my_df["D"].max())
# Out:
#    A     B     C   D
# 0  1   4.0  12.0  10
# 1  2  12.0   8.0  11
# 2  3  12.0   9.0  12

# %%
gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
by_year = gas_small.groupby("USA")

# %%
by_year.min()
# Out:
#       Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# USA
# 1.11  1993    1.67       1.73    1.45    3.41     3.07   3.68   4.16    1.48
# 1.13  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 1.14  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 1.16  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
#
#       South Korea    UK  Pakistan Saudi Arabia  Sweden
# USA
# 1.11         2.87  2.84      0.87         1.12     NaN
# 1.13         2.65  3.06      1.20         1.12     NaN
# 1.14         2.49  3.01      1.10         1.12     NaN
# 1.16         2.05  2.82      0.90         1.12     NaN

# %%
gas_small["USA"].value_counts()
# Out:
# USA
# 1.11    2
# 1.16    1
# 1.14    1
# 1.13    1
# Name: count, dtype: int64

# %%
pd.DataFrame(gas_small["USA"].value_counts())
# Out:
#       count
# USA
# 1.11      2
# 1.16      1
# 1.14      1
# 1.13      1

# %%
gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small["Italy"].unique()
# Out:
# array([4.59, 4.5 , 4.53, 3.68, 3.7 ])

# %%
pd.DataFrame(gas_small["Italy"].unique())
# Out:
#       0
# 0  4.59
# 1  4.50
# 2  4.53
# 3  3.68
# 4  3.70

# %%
def timesHundred(x):
    return x * 100

# %%
gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small["USA"].apply(timesHundred)
# Out:
# 0    116.0
# 1    114.0
# 2    113.0
# 3    111.0
# 4    111.0
# Name: USA, dtype: float64

# %%
pd.DataFrame(gas_small["USA"].apply(timesHundred))
# Out:
#      USA
# 0  116.0
# 1  114.0
# 2  113.0
# 3  111.0
# 4  111.0

# %%
gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
pd.DataFrame(gas_small["Italy"].apply(lambda x: x * 100))
# Out:
#    Italy
# 0  459.0
# 1  450.0
# 2  453.0
# 3  368.0
# 4  370.0

# %%
gas_small["Italy"] = gas_small["Italy"].apply(lambda x: x * 100)
gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990    1.67        NaN    1.87    3.63     2.65  459.0   3.16    1.00
# 1  1991    1.67       1.96    1.92    3.45     2.90  450.0   3.46    1.30
# 2  1992    1.67       1.89    1.73    3.56     3.27  453.0   3.58    1.50
# 3  1993    1.67       1.73    1.57    3.41     3.07  368.0   4.16    1.56
# 4  1994    1.67       1.84    1.45    3.59     3.52  370.0   4.36    1.48
#
#    South Korea    UK   USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  1.16      0.90         1.12     NaN
# 1         2.49  3.01  1.14      1.10         1.12     NaN
# 2         2.65  3.06  1.13      1.20         1.12     NaN
# 3         2.88  2.84  1.11      0.92         1.12     NaN
# 4         2.87  2.99  1.11      0.87         1.12     NaN

# %%
gas_small[["USA", "Kuwait", "Australia"]] = gas_small[
    ["USA", "Kuwait", "Australia"]
].apply(lambda x: x * 100)

gas_small
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990   167.0        NaN    1.87    3.63     2.65  459.0   3.16    1.00
# 1  1991   167.0      196.0    1.92    3.45     2.90  450.0   3.46    1.30
# 2  1992   167.0      189.0    1.73    3.56     3.27  453.0   3.58    1.50
# 3  1993   167.0      173.0    1.57    3.41     3.07  368.0   4.16    1.56
# 4  1994   167.0      184.0    1.45    3.59     3.52  370.0   4.36    1.48
#
#    South Korea    UK    USA  Pakistan Saudi Arabia  Sweden
# 0         2.05  2.82  116.0      0.90         1.12     NaN
# 1         2.49  3.01  114.0      1.10         1.12     NaN
# 2         2.65  3.06  113.0      1.20         1.12     NaN
# 3         2.88  2.84  111.0      0.92         1.12     NaN
# 4         2.87  2.99  111.0      0.87         1.12     NaN

# %%
gas_small.sort_values("South Korea", ascending=False, inplace=False)
# Out:
#    Year  Kuwait  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 3  1993   167.0      173.0    1.57    3.41     3.07  368.0   4.16    1.56
# 4  1994   167.0      184.0    1.45    3.59     3.52  370.0   4.36    1.48
# 2  1992   167.0      189.0    1.73    3.56     3.27  453.0   3.58    1.50
# 1  1991   167.0      196.0    1.92    3.45     2.90  450.0   3.46    1.30
# 0  1990   167.0        NaN    1.87    3.63     2.65  459.0   3.16    1.00
#
#    South Korea    UK    USA  Pakistan Saudi Arabia  Sweden
# 3         2.88  2.84  111.0      0.92         1.12     NaN
# 4         2.87  2.99  111.0      0.87         1.12     NaN
# 2         2.65  3.06  113.0      1.20         1.12     NaN
# 1         2.49  3.01  114.0      1.10         1.12     NaN
# 0         2.05  2.82  116.0      0.90         1.12     NaN

# %%
import matplotlib.pyplot as plt

gas_small["Australia"].hist(bins=10, grid=False, legend=True)
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# Create Dataframe
my_df = pd.DataFrame(randn(25, 4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#          Mon      Tues       Wed     Thurs
# 0   0.917581  0.017710  0.565804 -0.417690
# 1  -1.291556  0.239996  1.856148 -0.587801
# 2  -1.780249 -0.689999  0.883086 -0.372867
# 3  -0.900027 -0.159568 -1.260314  0.057373
# 4  -0.133147  0.008785  0.309597  0.065245
# 5  -1.161087 -1.551026  0.602366 -0.086319
# 6  -0.194536 -0.242788 -0.343288  1.561147
# 7   0.587827 -0.019067  1.412174  2.390458
# 8   0.962935  0.439454 -1.752684  1.090575
# 9   0.985013  1.354409 -0.370301  0.824466
# 10 -0.525059 -1.645236  0.746249  1.812255
# 11  0.554234  1.209714  0.435983  0.550079
# 12 -0.332479  0.986321  1.267179  1.033419
# 13  0.286523  0.285600 -0.187020 -0.629961
# 14 -0.047179  1.231810 -0.280489 -1.754001
# 15 -1.208479 -1.354313 -0.863195 -1.319423
# 16  0.307980 -0.340048  0.997346 -0.224431
# 17 -1.191772 -2.324586  1.304722  0.407987
# 18  1.283776  0.691022  1.029169 -0.218909
# 19 -0.244732 -0.667380 -0.430466  0.353880
# 20  0.284774  0.147924  0.109804  0.326804
# ...

# %%
# area plot
my_df.abs().plot(kind="area")
# Out:
# <Axes: >

# %%
my_df.abs().plot(kind="area", alpha=0.3, title="YOYO", legend=True)
# Out:
# <Axes: title={'center': 'YOYO'}>

# %%
my_df["Thurs"].abs().plot(kind="area", alpha=0.3, title="YOYO", legend=False)
# Out:
# <Axes: title={'center': 'YOYO'}>
